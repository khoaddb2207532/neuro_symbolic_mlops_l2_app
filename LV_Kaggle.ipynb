# %%
# !git config --global user.email "dangduykhoa9a6@gmail.com"
# !git config --global user.name "khoaddb2207532"

# %%
import os
from kaggle_secrets import UserSecretsClient

# 1. Lấy token an toàn từ Kaggle Secrets
user_secrets = UserSecretsClient()
github_token = user_secrets.get_secret("GITHUB_TOKEN")

# 2. Điền thông tin repo của bạn vào đây
username = "khoaddb2207532"
repo_name = "neuro_symbolic_mlops_l2_app"
branch_name = 'new_reward'

# 3. Tạo đường dẫn clone chứa token xác thực
# Định dạng: https://<token>@github.com/username/repo.git
repo_url = f"https://{github_token}@github.com/{username}/{repo_name}.git"

# 4. Thực hiện clone
print(f"Đang clone nhánh '{branch_name}' repo {repo_name}...")
os.system(f"git clone -b {branch_name} --single-branch {repo_url}")
print("Hoàn thành!")
# Out:
# Đang clone nhánh 'new_reward' repo neuro_symbolic_mlops_l2_app...
# Cloning into 'neuro_symbolic_mlops_l2_app'...
# Hoàn thành!

# %%
# %%bash
# # 1. Định nghĩa đường dẫn (Thay tên 'ten-notebook-cua-ban' bằng tên thực tế trong mục Input)
# SOURCE_DIR="/kaggle/input/notebooks/dangduykhoab2207532/lvfromgit-experiments/neuro_symbolic_mlops_l2_app/outputs"
# TARGET_DIR="/kaggle/working/neuro_symbolic_mlops_l2_app/outputs"
#
# # 2. Tạo thư mục đích trong /kaggle/working nếu chưa tồn tại
# mkdir -p "$TARGET_DIR"
#
# # 3. Tiến hành copy toàn bộ dữ liệu từ input sang
# # Sử dụng flag -r để copy thư mục con, -p để giữ nguyên thuộc tính file
# cp -rp "$SOURCE_DIR"/* "$TARGET_DIR"/
#
# # 4. Kiểm tra lại xem dữ liệu đã qua đủ chưa
# echo "=== Danh sách file đã copy thành công ==="
# ls -l "$TARGET_DIR"
# Out:
# === Danh sách file đã copy thành công ===
# total 16
# drwxr-xr-x 3 nobody nogroup 4096 Jul  7 06:19 01_baseline
# drwxr-xr-x 2 nobody nogroup 4096 Jul  7 06:19 02_features
# drwxr-xr-x 2 nobody nogroup 4096 Jul  7 06:19 03_rules
# drwxr-xr-x 2 nobody nogroup 4096 Jul  7 06:19 logs

# %%
# !pip install -q torchgfn dvclive dvc pyyaml
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 2.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.4/64.4 kB 4.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 54.6 MB/s eta 0:00:0000:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 2.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 470.1/470.1 kB 28.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.3/79.3 kB 4.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 451.2/451.2 kB 25.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.8/41.8 kB 2.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.0/45.0 kB 2.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.5/155.5 kB 10.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 214.2/214.2 kB 13.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 82.4 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.2/74.2 kB 4.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 59.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 559.5/559.5 kB 30.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 51.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 3.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 381.2/381.2 kB 23.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.1/87.1 kB 6.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 3.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 97.3 MB/s eta 0:00:00:00:01
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.39.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# google-adk 1.29.0 requires google-cloud-bigquery-storage>=2.0.0, which is not installed.
# kaggle-environments 1.29.3 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# sigstore 4.3.0 requires cryptography<49,>=42, but you have cryptography 49.0.0 which is incompatible.
# cesium 0.12.4 requires numpy<3.0,>=2.0, but you have numpy 1.26.4 which is incompatible.
# google-colab 1.0.0 requires jupyter-server==2.14.0, but you have jupyter-server 2.12.5 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.3.3 which is incompatible.
# dopamine-rl 4.1.2 requires gym<=0.25.2, but you have gym 0.26.2 which is incompatible.
# jaxlib 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# cupy-cuda12x 14.0.1 requires numpy<2.6,>=2.0, but you have numpy 1.26.4 which is incompatible.
# moviepy 1.0.3 requires decorator<5.0,>=4.0.2, but you have decorator 5.3.1 which is incompatible.
# opencv-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# tobler 0.14.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# jax 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# pydrive2 1.21.3 requires cryptography<44, but you have cryptography 49.0.0 which is incompatible.
# pyopenssl 24.2.1 requires cryptography<44,>=41.0.5, but you have cryptography 49.0.0 which is incompatible.
# opencv-python-headless 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# rasterio 1.5.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# pytensor 2.38.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# xarray-einstats 0.10.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# tifffile 2026.4.11 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# opencv-contrib-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# shap 0.51.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.

# %%
import yaml

# 1. Đọc (Load) file param.yaml
with open('/kaggle/working/neuro_symbolic_mlops_l2_app/params.yaml', 'r', encoding='utf-8') as file:
    params = yaml.safe_load(file)

# 2. Thay đổi nội dung (params hiện tại là một Dictionary)
params['data_dir'] =  "/kaggle/input/datasets/dangduykhoab2207532/vietnamese-cultural-dataset/vietnamese_cultural_dataset/vietnamese_cultural_dataset"
params['gflownet']['num_iterations'] = 5000
params['num_epochs'] = 5
params['gflownet']['max_rules'] = 120
params['gflownet']['beta'] = 1.0

print(yaml.dump(params, allow_unicode=True, default_flow_style=False))

# 3. Ghi đè (Save) lại vào file param.yaml
with open('/kaggle/working/neuro_symbolic_mlops_l2_app/params.yaml', 'w', encoding='utf-8') as file:
    yaml.safe_dump(params, file, default_flow_style=False, allow_unicode=True)

print("\n--- Đã cập nhật thành công file param.yaml! ---")
# Out:
# batch_size: 64
# data_dir: /kaggle/input/datasets/dangduykhoab2207532/vietnamese-cultural-dataset/vietnamese_cultural_dataset/vietnamese_cultural_dataset
# gflownet:
#   batch_size: 256
#   beta: 1.0
#   grad_clip_max_norm: None
#   hidden_dim: 256
#   logZ_lr: 0.1
#   logZ_warmup_steps: 50
#   loss_type: tb
#   lr: 0.001
#   max_rules: 120
#   num_iterations: 5000
#   val_samples: 140
#   validation_interval: 100
#   w_acc: 1.0
#   w_conflict: 0.5
#   w_cov: 0.5
# monitor_metric: val_loss
# num_classes: 12
# num_epochs: 5
# num_workers: 4
# output_dir: outputs
# patience: 5
# rule_penalty:
#   final_temp: 15.0
#   initial_temp: 2.0
#   smoothing: 0.1
#   weight: 0.1
# rule_penalty_bayesian:
#   K: 32
#   resolve_loss_conflict: true
# rule_ranking_analysis:
#   K: 300
# rules:
#   min_confidence: 0.7
#   min_support: 0.01
# seed: 42
# transfer_learning:
#   freeze_bn: true
#   freeze_schedule:
#     0: head_only
#     5: last_block
#     15: full
#   freeze_schedule_stage2:
#     0: last_block
#     10: full
#   lr_backbone: 1.0e-05
#   lr_head: 0.0001
# weight_decay: 0.0001
#
#
# --- Đã cập nhật thành công file param.yaml! ---

# %%
# %cd neuro_symbolic_mlops_l2_app
# Out:
# /kaggle/working/neuro_symbolic_mlops_l2_app

# %%
# %cd /kaggle/working

# %%
# !python -m pipelines.stage1_train_baseline --config /kaggle/working/neuro_symbolic_mlops_l2_app/params.yaml

# %%
# !python -m pipelines.stage2_extract_features --config /kaggle/working/neuro_symbolic_mlops_l2_app/params.yaml

# %%
# !python -m pipelines.stage3_extract_rules --config/kaggle/working/neuro_symbolic_mlops_l2_app/params.yaml

# %%
# !python -m experiments.sweep_reward_weights --config /kaggle/working/neuro_symbolic_mlops_l2_app/params.yaml

# %%
# !python -m pipelines.stage4_select_rules_gflownet --config /kaggle/working/neuro_symbolic_mlops_l2_app/params.yaml
# Out:
# Validate + build tensors: 100%|█████████████████| 33/33 [00:51<00:00,  1.56s/it]
# 2026-07-08 17:31:27 | INFO     | __main__ | Số luật hợp lệ sau khi lọc bằng val set: 1369
# 2026-07-08 17:31:27 | INFO     | src.gflownet.pipeline | Số luật hợp lệ: 1369 | loss_type: tb
# 2026-07-08 17:31:28 | INFO     | src.gflownet.pipeline | Đã lưu rule order + tensor (khớp index với gflownet_best.pth) tại outputs/04_filtered_rules/gflownet_rule_order.pkl
# GFlowNet (torchgfn):   2%| | 99/5000 [00:53<45:41,  1.79it/s, avg_log_r=1.259, g2026-07-08 17:32:24 | INFO     | src.gflownet.pipeline | Iter 100: ema=1.2550 best (120 rules)
# 2026-07-08 17:32:24 | INFO     | src.gflownet.pipeline | Loss= 3775.5720 : avg_log_r= 1.2587 : logZ= 7.6238 : grad_norm= 23226.0254 : lr= 0.001
# GFlowNet (torchgfn):   4%| | 199/5000 [01:29<14:21,  5.57it/s, avg_log_r=1.016, 2026-07-08 17:32:58 | INFO     | src.gflownet.pipeline | Iter 200: ema=1.1805 best (120 rules)
# 2026-07-08 17:32:58 | INFO     | src.gflownet.pipeline | Loss= 606.8253 : avg_log_r= 1.0160 : logZ= 9.1739 : grad_norm= 480.7326 : lr= 0.001
# GFlowNet (torchgfn):   6%| | 299/5000 [01:45<11:30,  6.81it/s, avg_log_r=0.954, 2026-07-08 17:33:14 | INFO     | src.gflownet.pipeline | Iter 300: ema=1.1165 best (120 rules)
# 2026-07-08 17:33:14 | INFO     | src.gflownet.pipeline | Loss= 186.9279 : avg_log_r= 0.9539 : logZ= 9.8672 : grad_norm= 98.8624 : lr= 0.001
# GFlowNet (torchgfn):   8%| | 399/5000 [02:00<11:42,  6.55it/s, avg_log_r=0.953, 2026-07-08 17:33:30 | INFO     | src.gflownet.pipeline | Iter 400: ema=1.0661 best (120 rules)
# 2026-07-08 17:33:30 | INFO     | src.gflownet.pipeline | Loss= 165.3242 : avg_log_r= 0.9528 : logZ= 10.3989 : grad_norm= 75.2095 : lr= 0.001
# GFlowNet (torchgfn):  10%| | 499/5000 [02:16<11:34,  6.48it/s, avg_log_r=0.957, 2026-07-08 17:33:45 | INFO     | src.gflownet.pipeline | Iter 500: ema=1.0332 best (120 rules)
# 2026-07-08 17:33:45 | INFO     | src.gflownet.pipeline | Loss= 151.7162 : avg_log_r= 0.9567 : logZ= 10.9619 : grad_norm= 76.0500 : lr= 0.0005
# GFlowNet (torchgfn):  12%| | 599/5000 [02:31<11:04,  6.62it/s, avg_log_r=0.959, 2026-07-08 17:34:01 | INFO     | src.gflownet.pipeline | Iter 600: ema=1.0133 best (120 rules)
# 2026-07-08 17:34:01 | INFO     | src.gflownet.pipeline | Loss= 151.3183 : avg_log_r= 0.9589 : logZ= 11.2603 : grad_norm= 81.8425 : lr= 0.0005
# GFlowNet (torchgfn):  14%|▏| 699/5000 [02:47<10:56,  6.55it/s, avg_log_r=0.970, 2026-07-08 17:34:17 | INFO     | src.gflownet.pipeline | Iter 700: ema=0.9990 best (120 rules)
# 2026-07-08 17:34:17 | INFO     | src.gflownet.pipeline | Loss= 147.7182 : avg_log_r= 0.9700 : logZ= 11.5879 : grad_norm= 80.6640 : lr= 0.0005
# GFlowNet (torchgfn):  16%|▏| 799/5000 [03:04<11:35,  6.04it/s, avg_log_r=0.970, 2026-07-08 17:34:33 | INFO     | src.gflownet.pipeline | Iter 800: ema=0.9886 best (120 rules)
# 2026-07-08 17:34:33 | INFO     | src.gflownet.pipeline | Loss= 141.5733 : avg_log_r= 0.9702 : logZ= 11.9370 : grad_norm= 85.5823 : lr= 0.0005
# GFlowNet (torchgfn):  18%|▏| 899/5000 [03:20<11:21,  6.02it/s, avg_log_r=0.971, 2026-07-08 17:34:50 | INFO     | src.gflownet.pipeline | Iter 900: ema=0.9833 best (120 rules)
# 2026-07-08 17:34:50 | INFO     | src.gflownet.pipeline | Loss= 143.6462 : avg_log_r= 0.9714 : logZ= 12.3213 : grad_norm= 78.2636 : lr= 0.00025
# GFlowNet (torchgfn):  20%|▏| 999/5000 [03:37<11:08,  5.99it/s, avg_log_r=0.966, 2026-07-08 17:35:07 | INFO     | src.gflownet.pipeline | Iter 1000: ema=0.9785 best (120 rules)
# 2026-07-08 17:35:07 | INFO     | src.gflownet.pipeline | Loss= 126.6209 : avg_log_r= 0.9661 : logZ= 12.5282 : grad_norm= 72.2072 : lr= 0.00025
# GFlowNet (torchgfn):  22%|▏| 1099/5000 [03:54<11:12,  5.80it/s, avg_log_r=0.973,2026-07-08 17:35:24 | INFO     | src.gflownet.pipeline | Iter 1100: ema=0.9764 best (120 rules)
# 2026-07-08 17:35:24 | INFO     | src.gflownet.pipeline | Loss= 143.8552 : avg_log_r= 0.9728 : logZ= 12.7560 : grad_norm= 84.6519 : lr= 0.00025
# GFlowNet (torchgfn):  24%|▏| 1199/5000 [04:12<11:13,  5.64it/s, avg_log_r=0.972,2026-07-08 17:35:42 | INFO     | src.gflownet.pipeline | Iter 1200: ema=0.9746 best (120 rules)
# 2026-07-08 17:35:42 | INFO     | src.gflownet.pipeline | Loss= 135.7622 : avg_log_r= 0.9723 : logZ= 12.9982 : grad_norm= 85.2854 : lr= 0.00025
# GFlowNet (torchgfn):  26%|▎| 1299/5000 [04:30<11:01,  5.59it/s, avg_log_r=0.974,2026-07-08 17:36:00 | INFO     | src.gflownet.pipeline | Iter 1300: ema=0.9740 best (120 rules)
# 2026-07-08 17:36:00 | INFO     | src.gflownet.pipeline | Loss= 138.4679 : avg_log_r= 0.9739 : logZ= 13.2658 : grad_norm= 86.3010 : lr= 0.000125
# GFlowNet (torchgfn):  28%|▎| 1399/5000 [04:49<11:05,  5.41it/s, avg_log_r=0.976,2026-07-08 17:36:18 | INFO     | src.gflownet.pipeline | Iter 1400: ema=0.9740 best (120 rules)
# 2026-07-08 17:36:18 | INFO     | src.gflownet.pipeline | Loss= 143.3225 : avg_log_r= 0.9756 : logZ= 13.4111 : grad_norm= 91.2690 : lr= 0.000125
# GFlowNet (torchgfn):  30%|▎| 1499/5000 [05:08<11:01,  5.30it/s, avg_log_r=0.976,2026-07-08 17:36:38 | INFO     | src.gflownet.pipeline | Iter 1500: ema=0.9749 best (120 rules)
# 2026-07-08 17:36:38 | INFO     | src.gflownet.pipeline | Loss= 135.3636 : avg_log_r= 0.9757 : logZ= 13.5679 : grad_norm= 92.8659 : lr= 0.000125
# GFlowNet (torchgfn):  32%|▎| 1599/5000 [05:27<10:53,  5.20it/s, avg_log_r=0.973,2026-07-08 17:36:57 | INFO     | src.gflownet.pipeline | Iter 1600: ema=0.9757 best (120 rules)
# 2026-07-08 17:36:57 | INFO     | src.gflownet.pipeline | Loss= 160.1127 : avg_log_r= 0.9728 : logZ= 13.7343 : grad_norm= 114.9580 : lr= 0.000125
# GFlowNet (torchgfn):  34%|▎| 1699/5000 [05:47<10:44,  5.12it/s, avg_log_r=0.973,2026-07-08 17:37:17 | INFO     | src.gflownet.pipeline | Iter 1700: ema=0.9761 best (120 rules)
# 2026-07-08 17:37:17 | INFO     | src.gflownet.pipeline | Loss= 151.6022 : avg_log_r= 0.9730 : logZ= 13.9171 : grad_norm= 107.7929 : lr= 6.25e-05
# GFlowNet (torchgfn):  36%|▎| 1799/5000 [06:07<10:44,  4.97it/s, avg_log_r=0.991,2026-07-08 17:37:37 | INFO     | src.gflownet.pipeline | Iter 1800: ema=0.9780 best (120 rules)
# 2026-07-08 17:37:37 | INFO     | src.gflownet.pipeline | Loss= 147.5215 : avg_log_r= 0.9909 : logZ= 14.0180 : grad_norm= 112.8780 : lr= 6.25e-05
# GFlowNet (torchgfn):  38%|▍| 1899/5000 [06:28<10:38,  4.85it/s, avg_log_r=0.986,2026-07-08 17:37:57 | INFO     | src.gflownet.pipeline | Iter 1900: ema=0.9802 best (120 rules)
# 2026-07-08 17:37:57 | INFO     | src.gflownet.pipeline | Loss= 158.7764 : avg_log_r= 0.9862 : logZ= 14.1258 : grad_norm= 132.0326 : lr= 6.25e-05
# GFlowNet (torchgfn):  40%|▍| 1999/5000 [06:49<10:22,  4.82it/s, avg_log_r=0.984,2026-07-08 17:38:19 | INFO     | src.gflownet.pipeline | Iter 2000: ema=0.9826 best (120 rules)
# 2026-07-08 17:38:19 | INFO     | src.gflownet.pipeline | Loss= 181.8347 : avg_log_r= 0.9843 : logZ= 14.2369 : grad_norm= 133.2939 : lr= 6.25e-05
# GFlowNet (torchgfn):  42%|▍| 2099/5000 [07:10<10:09,  4.76it/s, avg_log_r=0.988,2026-07-08 17:38:40 | INFO     | src.gflownet.pipeline | Iter 2100: ema=0.9834 best (120 rules)
# 2026-07-08 17:38:40 | INFO     | src.gflownet.pipeline | Loss= 153.6142 : avg_log_r= 0.9884 : logZ= 14.3552 : grad_norm= 127.3668 : lr= 3.125e-05
# GFlowNet (torchgfn):  44%|▍| 2199/5000 [07:32<09:56,  4.69it/s, avg_log_r=0.993,2026-07-08 17:39:02 | INFO     | src.gflownet.pipeline | Iter 2200: ema=0.9852 best (120 rules)
# 2026-07-08 17:39:02 | INFO     | src.gflownet.pipeline | Loss= 168.0913 : avg_log_r= 0.9927 : logZ= 14.4162 : grad_norm= 133.7762 : lr= 3.125e-05
# GFlowNet (torchgfn):  46%|▍| 2299/5000 [07:54<09:47,  4.60it/s, avg_log_r=0.993,2026-07-08 17:39:24 | INFO     | src.gflownet.pipeline | Iter 2300: ema=0.9848 best (120 rules)
# 2026-07-08 17:39:24 | INFO     | src.gflownet.pipeline | Loss= 182.0314 : avg_log_r= 0.9931 : logZ= 14.4809 : grad_norm= 145.3687 : lr= 3.125e-05
# GFlowNet (torchgfn):  48%|▍| 2399/5000 [08:16<09:35,  4.52it/s, avg_log_r=0.986,2026-07-08 17:39:46 | INFO     | src.gflownet.pipeline | Iter 2400: ema=0.9869 best (120 rules)
# 2026-07-08 17:39:46 | INFO     | src.gflownet.pipeline | Loss= 140.5129 : avg_log_r= 0.9856 : logZ= 14.5479 : grad_norm= 103.3847 : lr= 3.125e-05
# GFlowNet (torchgfn):  50%|▍| 2499/5000 [08:39<09:27,  4.41it/s, avg_log_r=0.984,2026-07-08 17:40:08 | INFO     | src.gflownet.pipeline | Iter 2500: ema=0.9880 best (120 rules)
# 2026-07-08 17:40:08 | INFO     | src.gflownet.pipeline | Loss= 141.2064 : avg_log_r= 0.9837 : logZ= 14.6189 : grad_norm= 128.5688 : lr= 1.5625e-05
# GFlowNet (torchgfn):  52%|▌| 2599/5000 [09:02<09:07,  4.38it/s, avg_log_r=0.985,2026-07-08 17:40:32 | INFO     | src.gflownet.pipeline | Iter 2600: ema=0.9887 best (120 rules)
# 2026-07-08 17:40:32 | INFO     | src.gflownet.pipeline | Loss= 145.6598 : avg_log_r= 0.9846 : logZ= 14.6569 : grad_norm= 107.5992 : lr= 1.5625e-05
# GFlowNet (torchgfn):  54%|▌| 2699/5000 [09:25<09:09,  4.19it/s, avg_log_r=0.990,2026-07-08 17:40:55 | INFO     | src.gflownet.pipeline | Iter 2700: ema=0.9898 best (120 rules)
# 2026-07-08 17:40:55 | INFO     | src.gflownet.pipeline | Loss= 166.0746 : avg_log_r= 0.9905 : logZ= 14.6965 : grad_norm= 119.7839 : lr= 1.5625e-05
# GFlowNet (torchgfn):  56%|▌| 2799/5000 [09:49<08:32,  4.29it/s, avg_log_r=0.979,2026-07-08 17:41:18 | INFO     | src.gflownet.pipeline | Iter 2800: ema=0.9898 best (120 rules)
# 2026-07-08 17:41:18 | INFO     | src.gflownet.pipeline | Loss= 178.0823 : avg_log_r= 0.9793 : logZ= 14.7381 : grad_norm= 129.6498 : lr= 1.5625e-05
# GFlowNet (torchgfn):  58%|▌| 2899/5000 [10:13<08:16,  4.23it/s, avg_log_r=0.991,2026-07-08 17:41:43 | INFO     | src.gflownet.pipeline | Iter 2900: ema=0.9913 best (120 rules)
# 2026-07-08 17:41:43 | INFO     | src.gflownet.pipeline | Loss= 154.9583 : avg_log_r= 0.9914 : logZ= 14.7824 : grad_norm= 114.5095 : lr= 7.8125e-06
# GFlowNet (torchgfn):  60%|▌| 2999/5000 [10:37<08:05,  4.12it/s, avg_log_r=0.995,2026-07-08 17:42:07 | INFO     | src.gflownet.pipeline | Iter 3000: ema=0.9934 best (120 rules)
# 2026-07-08 17:42:07 | INFO     | src.gflownet.pipeline | Loss= 128.1665 : avg_log_r= 0.9951 : logZ= 14.8055 : grad_norm= 129.5856 : lr= 7.8125e-06
# GFlowNet (torchgfn):  62%|▌| 3099/5000 [11:02<07:33,  4.19it/s, avg_log_r=0.995,2026-07-08 17:42:31 | INFO     | src.gflownet.pipeline | Iter 3100: ema=0.9935 best (120 rules)
# 2026-07-08 17:42:31 | INFO     | src.gflownet.pipeline | Loss= 136.9966 : avg_log_r= 0.9951 : logZ= 14.8295 : grad_norm= 129.1737 : lr= 7.8125e-06
# GFlowNet (torchgfn):  64%|▋| 3199/5000 [11:26<07:18,  4.10it/s, avg_log_r=0.994,2026-07-08 17:42:56 | INFO     | src.gflownet.pipeline | Iter 3200: ema=0.9945 best (120 rules)
# 2026-07-08 17:42:56 | INFO     | src.gflownet.pipeline | Loss= 174.8539 : avg_log_r= 0.9935 : logZ= 14.8551 : grad_norm= 126.6523 : lr= 7.8125e-06
# GFlowNet (torchgfn):  66%|▋| 3299/5000 [11:51<07:00,  4.05it/s, avg_log_r=0.992,2026-07-08 17:43:21 | INFO     | src.gflownet.pipeline | Iter 3300: ema=0.9945 best (120 rules)
# 2026-07-08 17:43:21 | INFO     | src.gflownet.pipeline | Loss= 149.4871 : avg_log_r= 0.9919 : logZ= 14.8815 : grad_norm= 122.7846 : lr= 3.90625e-06
# GFlowNet (torchgfn):  68%|▋| 3399/5000 [12:16<06:43,  3.97it/s, avg_log_r=0.998,2026-07-08 17:43:46 | INFO     | src.gflownet.pipeline | Iter 3400: ema=0.9954 best (120 rules)
# 2026-07-08 17:43:46 | INFO     | src.gflownet.pipeline | Loss= 143.8469 : avg_log_r= 0.9978 : logZ= 14.8953 : grad_norm= 123.8666 : lr= 3.90625e-06
# GFlowNet (torchgfn):  70%|▋| 3499/5000 [12:42<06:09,  4.06it/s, avg_log_r=0.990,2026-07-08 17:44:11 | INFO     | src.gflownet.pipeline | Iter 3500: ema=0.9954 best (120 rules)
# 2026-07-08 17:44:11 | INFO     | src.gflownet.pipeline | Loss= 159.2972 : avg_log_r= 0.9897 : logZ= 14.9099 : grad_norm= 128.1049 : lr= 3.90625e-06
# GFlowNet (torchgfn):  72%|▋| 3599/5000 [13:07<05:51,  3.98it/s, avg_log_r=0.998,2026-07-08 17:44:37 | INFO     | src.gflownet.pipeline | Iter 3600: ema=0.9938 best (120 rules)
# 2026-07-08 17:44:37 | INFO     | src.gflownet.pipeline | Loss= 140.3842 : avg_log_r= 0.9979 : logZ= 14.9249 : grad_norm= 105.2186 : lr= 3.90625e-06
# GFlowNet (torchgfn):  74%|▋| 3699/5000 [13:33<05:38,  3.84it/s, avg_log_r=0.999,2026-07-08 17:45:03 | INFO     | src.gflownet.pipeline | Iter 3700: ema=0.9941 best (120 rules)
# 2026-07-08 17:45:03 | INFO     | src.gflownet.pipeline | Loss= 143.8018 : avg_log_r= 0.9993 : logZ= 14.9407 : grad_norm= 128.9481 : lr= 1.95313e-06
# GFlowNet (torchgfn):  76%|▊| 3799/5000 [14:00<07:52,  2.54it/s, avg_log_r=0.992,2026-07-08 17:45:30 | INFO     | src.gflownet.pipeline | Iter 3800: ema=0.9951 best (120 rules)
# 2026-07-08 17:45:30 | INFO     | src.gflownet.pipeline | Loss= 177.6740 : avg_log_r= 0.9920 : logZ= 14.9488 : grad_norm= 143.2162 : lr= 1.95313e-06
# GFlowNet (torchgfn):  78%|▊| 3899/5000 [14:27<04:56,  3.71it/s, avg_log_r=0.993,2026-07-08 17:45:57 | INFO     | src.gflownet.pipeline | Iter 3900: ema=0.9956 best (120 rules)
# 2026-07-08 17:45:57 | INFO     | src.gflownet.pipeline | Loss= 134.9444 : avg_log_r= 0.9934 : logZ= 14.9573 : grad_norm= 124.7986 : lr= 1.95313e-06
# GFlowNet (torchgfn):  80%|▊| 3999/5000 [14:54<04:27,  3.74it/s, avg_log_r=0.991,2026-07-08 17:46:24 | INFO     | src.gflownet.pipeline | Iter 4000: ema=0.9958 best (120 rules)
# 2026-07-08 17:46:24 | INFO     | src.gflownet.pipeline | Loss= 146.7896 : avg_log_r= 0.9906 : logZ= 14.9661 : grad_norm= 123.4547 : lr= 1.95313e-06
# GFlowNet (torchgfn):  82%|▊| 4099/5000 [15:22<04:05,  3.68it/s, avg_log_r=1.000,2026-07-08 17:46:52 | INFO     | src.gflownet.pipeline | Iter 4100: ema=0.9961 best (120 rules)
# 2026-07-08 17:46:52 | INFO     | src.gflownet.pipeline | Loss= 146.2168 : avg_log_r= 0.9997 : logZ= 14.9753 : grad_norm= 153.6055 : lr= 9.76563e-07
# GFlowNet (torchgfn):  84%|▊| 4199/5000 [15:50<03:42,  3.61it/s, avg_log_r=0.979,2026-07-08 17:47:19 | INFO     | src.gflownet.pipeline | Iter 4200: ema=0.9964 best (120 rules)
# 2026-07-08 17:47:19 | INFO     | src.gflownet.pipeline | Loss= 149.1403 : avg_log_r= 0.9788 : logZ= 14.9800 : grad_norm= 140.9833 : lr= 9.76563e-07
# GFlowNet (torchgfn):  86%|▊| 4299/5000 [16:18<03:14,  3.61it/s, avg_log_r=0.994,2026-07-08 17:47:48 | INFO     | src.gflownet.pipeline | Iter 4300: ema=0.9961 best (120 rules)
# 2026-07-08 17:47:48 | INFO     | src.gflownet.pipeline | Loss= 158.2424 : avg_log_r= 0.9938 : logZ= 14.9850 : grad_norm= 114.5189 : lr= 9.76563e-07
# GFlowNet (torchgfn):  88%|▉| 4399/5000 [16:46<02:50,  3.52it/s, avg_log_r=0.993,2026-07-08 17:48:16 | INFO     | src.gflownet.pipeline | Iter 4400: ema=0.9968 best (120 rules)
# 2026-07-08 17:48:16 | INFO     | src.gflownet.pipeline | Loss= 143.0861 : avg_log_r= 0.9928 : logZ= 14.9901 : grad_norm= 117.3920 : lr= 9.76563e-07
# GFlowNet (torchgfn):  90%|▉| 4499/5000 [17:16<02:28,  3.37it/s, avg_log_r=0.992,2026-07-08 17:48:45 | INFO     | src.gflownet.pipeline | Iter 4500: ema=0.9960 best (120 rules)
# 2026-07-08 17:48:45 | INFO     | src.gflownet.pipeline | Loss= 157.6050 : avg_log_r= 0.9919 : logZ= 14.9956 : grad_norm= 115.9751 : lr= 4.88281e-07
# GFlowNet (torchgfn):  92%|▉| 4599/5000 [17:45<01:58,  3.38it/s, avg_log_r=1.000,2026-07-08 17:49:14 | INFO     | src.gflownet.pipeline | Iter 4600: ema=0.9962 best (120 rules)
# 2026-07-08 17:49:14 | INFO     | src.gflownet.pipeline | Loss= 141.6457 : avg_log_r= 0.9999 : logZ= 14.9983 : grad_norm= 121.9095 : lr= 4.88281e-07
# GFlowNet (torchgfn):  94%|▉| 4699/5000 [18:15<01:29,  3.36it/s, avg_log_r=0.999,2026-07-08 17:49:44 | INFO     | src.gflownet.pipeline | Iter 4700: ema=0.9955 best (120 rules)
# 2026-07-08 17:49:44 | INFO     | src.gflownet.pipeline | Loss= 165.7971 : avg_log_r= 0.9991 : logZ= 15.0012 : grad_norm= 137.3347 : lr= 4.88281e-07
# GFlowNet (torchgfn):  96%|▉| 4799/5000 [18:45<01:00,  3.30it/s, avg_log_r=1.000,2026-07-08 17:50:15 | INFO     | src.gflownet.pipeline | Iter 4800: ema=0.9945 best (120 rules)
# 2026-07-08 17:50:15 | INFO     | src.gflownet.pipeline | Loss= 138.9194 : avg_log_r= 0.9997 : logZ= 15.0042 : grad_norm= 107.6233 : lr= 4.88281e-07
# GFlowNet (torchgfn):  98%|▉| 4899/5000 [19:15<00:31,  3.18it/s, avg_log_r=0.993,2026-07-08 17:50:45 | INFO     | src.gflownet.pipeline | Iter 4900: ema=0.9949 best (120 rules)
# 2026-07-08 17:50:45 | INFO     | src.gflownet.pipeline | Loss= 165.9129 : avg_log_r= 0.9928 : logZ= 15.0072 : grad_norm= 116.4190 : lr= 2.44141e-07
# GFlowNet (torchgfn): 100%|▉| 4999/5000 [19:47<00:00,  3.26it/s, avg_log_r=0.998,2026-07-08 17:51:16 | INFO     | src.gflownet.pipeline | Iter 5000: ema=0.9959 best (120 rules)
# 2026-07-08 17:51:16 | INFO     | src.gflownet.pipeline | Loss= 148.4233 : avg_log_r= 0.9977 : logZ= 15.0088 : grad_norm= 123.9879 : lr= 2.44141e-07
# GFlowNet (torchgfn): 100%|█| 5000/5000 [19:47<00:00,  4.21it/s, avg_log_r=0.998,
# 2026-07-08 17:51:17 | INFO     | src.gflownet.pipeline | DEBUG best_selected_ever: n_selected=120, accuracy=0.9140, coverage=0.9019, redundancy=0.0252, redundancy_conflict=0.1570, complexity=1.0000, f1_like=0.9079
# 2026-07-08 17:51:17 | INFO     | src.gflownet.pipeline | DEBUG final_selected (returned): n_selected=120, accuracy=0.9140, coverage=0.9019, redundancy=0.0252, redundancy_conflict=0.1570, complexity=1.0000, f1_like=0.9079
# 2026-07-08 17:51:17 | INFO     | src.gflownet.pipeline | Final: 120 rules, best=1.2864
#   0% Committing outputs/02_features to cache|        |0/7 [00:00<?,     ?file/s]
# !
#   0%|          |memory://.1tIoriIWzHAlrbQy_GyfnA.0.00/450 [00:00<?,        ?B/s]
# WARNING:dvclive:Error in save_dvc_exp: output 'outputs/04_filtered_rules/selected_rules.pkl' does not exist
# 2026-07-08 17:51:19 | INFO     | __main__ | Stage 4 hoàn thành. 120 luật được GFlowNet chọn.

# %%
# !python -m pipelines.stage5_train_rule_regularized --config /kaggle/working/neuro_symbolic_mlops_l2_app/params.yaml

# %%
# !python -m pipelines.stage5_train_rule_regularized_heuristics  --config /kaggle/working/neuro_symbolic_mlops_l2_app/params.yaml

# %%
! python -m pipelines.stage5_train_rule_bayesian --config /kaggle/working/neuro_symbolic_mlops_l2_app/params.yaml
# Out:
# 2026-07-08 17:51:36 | INFO     | __main__ | Đã nạp frozen GFlowNet sampler từ outputs/04_filtered_rules/gflownet_best_sampler.pth (1369 luật, loss_type=tb).
# Downloading: "https://download.pytorch.org/models/mobilenet_v3_large-5c1a4163.pth" to /root/.cache/torch/hub/checkpoints/mobilenet_v3_large-5c1a4163.pth
# 100%|███████████████████████████████████████| 21.1M/21.1M [00:00<00:00, 123MB/s]
# 2026-07-08 17:51:38 | INFO     | src.training.trainer | EarlyStopping theo dõi 'val_loss' (mode='min')
# 2026-07-08 17:51:38 | INFO     | src.training.trainer | Dùng penalty_module được truyền sẵn: BayesianRuleMarginalization
# 2026-07-08 17:51:38 | INFO     | src.training.trainer | Bật xử lý xung đột gradient (PCGrad) giữa CE loss và rule-penalty loss.
# 2026-07-08 17:51:39 | INFO     | src.training.trainer | Epoch 0: chuyển freeze_stage -> 'head_only'
# 2026-07-08 17:52:53 | INFO     | src.training.trainer | Epoch 1/5 | Train Loss 1.9738 | Train Acc 0.6147 | CE 1.7422 | Penalty 0.2316 | Val Loss 1.1630 | Val Acc 0.8215 | LRs head:1.00e-04
# 2026-07-08 17:52:53 | INFO     | src.training.trainer |   Rule coverage: 39/1369 luật active (2.9%) | mean_rule_sat=0.0037 | T=2.00 | grad_conflict_ratio=0.79
# 2026-07-08 17:53:57 | INFO     | src.training.trainer | Epoch 2/5 | Train Loss 1.3896 | Train Acc 0.7857 | CE 1.1561 | Penalty 0.2335 | Val Loss 0.9681 | Val Acc 0.8584 | LRs head:1.00e-04
# 2026-07-08 17:53:57 | INFO     | src.training.trainer |   Rule coverage: 133/1369 luật active (9.7%) | mean_rule_sat=0.0063 | T=5.25 | grad_conflict_ratio=0.99
# 2026-07-08 17:55:00 | INFO     | src.training.trainer | Epoch 3/5 | Train Loss 1.2575 | Train Acc 0.8204 | CE 1.0478 | Penalty 0.2098 | Val Loss 0.9059 | Val Acc 0.8785 | LRs head:1.00e-04
# 2026-07-08 17:55:00 | INFO     | src.training.trainer |   Rule coverage: 203/1369 luật active (14.8%) | mean_rule_sat=0.0077 | T=8.50 | grad_conflict_ratio=0.92
# 2026-07-08 17:56:05 | INFO     | src.training.trainer | Epoch 4/5 | Train Loss 1.1883 | Train Acc 0.8355 | CE 0.9995 | Penalty 0.1888 | Val Loss 0.8781 | Val Acc 0.8911 | LRs head:1.00e-04
# 2026-07-08 17:56:05 | INFO     | src.training.trainer |   Rule coverage: 245/1369 luật active (17.9%) | mean_rule_sat=0.0086 | T=11.75 | grad_conflict_ratio=0.88
# 2026-07-08 17:57:09 | INFO     | src.training.trainer | Epoch 5/5 | Train Loss 1.1369 | Train Acc 0.8499 | CE 0.9630 | Penalty 0.1739 | Val Loss 0.8593 | Val Acc 0.8958 | LRs head:1.00e-04
# 2026-07-08 17:57:09 | INFO     | src.training.trainer |   Rule coverage: 283/1369 luật active (20.7%) | mean_rule_sat=0.0093 | T=15.00 | grad_conflict_ratio=0.85
# WARNING:dvclive:Error in save_dvc_exp: output 'outputs/04_filtered_rules/rule_ranking_analysis.csv' does not exist
# 2026-07-08 17:57:10 | INFO     | src.training.trainer | Nhiệt độ dừng ở 15.00 (100.0% quãng đường ủ dự kiến)
# 2026-07-08 17:57:10 | INFO     | src.training.trainer | Training complete in 5.54 minutes | Best Val Acc: 0.8958
# 2026-07-08 17:57:18 | INFO     | src.evaluation.evaluate | Rule-Regularized CNN Performance (Bayesian marginalization) | Overall Accuracy: 88.28%
# 2026-07-08 17:57:21 | INFO     | __main__ | Stage 5 (Bayesian marginalization) hoàn thành.
