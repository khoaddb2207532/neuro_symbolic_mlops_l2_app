# %%
# !git config --global user.email "dangduykhoa9a6@gmail.com"
# !git config --global user.name "khoaddb2207532"

# %%
import os
from kaggle_secrets import UserSecretsClient

# 1. Lấy token an toàn từ Kaggle Secrets
user_secrets = UserSecretsClient()
github_token = user_secrets.get_secret("GITHUB_TOKEN")

# 2. Điền thông tin repo của bạn vào đây
username = "khoaddb2207532"
repo_name = "neuro_symbolic_mlops_l2_app"
branch_name = 'new_reward'

# 3. Tạo đường dẫn clone chứa token xác thực
# Định dạng: https://<token>@github.com/username/repo.git
repo_url = f"https://{github_token}@github.com/{username}/{repo_name}.git"

# 4. Thực hiện clone
print(f"Đang clone nhánh '{branch_name}' repo {repo_name}...")
os.system(f"git clone -b {branch_name} --single-branch {repo_url}")
print("Hoàn thành!")
# Out:
# Đang clone nhánh 'new_reward' repo neuro_symbolic_mlops_l2_app...
# Cloning into 'neuro_symbolic_mlops_l2_app'...
# Hoàn thành!

# %%
# %%bash
# # 1. Định nghĩa đường dẫn (Thay tên 'ten-notebook-cua-ban' bằng tên thực tế trong mục Input)
# SOURCE_DIR="/kaggle/input/notebooks/dangduykhoab2207532/lvfromgit-experiments/neuro_symbolic_mlops_l2_app/outputs"
# TARGET_DIR="/kaggle/working/neuro_symbolic_mlops_l2_app/outputs"
#
# # 2. Tạo thư mục đích trong /kaggle/working nếu chưa tồn tại
# mkdir -p "$TARGET_DIR"
#
# # 3. Tiến hành copy toàn bộ dữ liệu từ input sang
# # Sử dụng flag -r để copy thư mục con, -p để giữ nguyên thuộc tính file
# cp -rp "$SOURCE_DIR"/* "$TARGET_DIR"/
#
# # 4. Kiểm tra lại xem dữ liệu đã qua đủ chưa
# echo "=== Danh sách file đã copy thành công ==="
# ls -l "$TARGET_DIR"
# Out:
# === Danh sách file đã copy thành công ===
# total 16
# drwxr-xr-x 3 nobody nogroup 4096 Jul  7 17:38 01_baseline
# drwxr-xr-x 2 nobody nogroup 4096 Jul  7 17:38 02_features
# drwxr-xr-x 2 nobody nogroup 4096 Jul  7 17:38 03_rules
# drwxr-xr-x 2 nobody nogroup 4096 Jul  7 17:38 logs

# %%
# !pip install -q torchgfn dvclive dvc pyyaml
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 105.1 kB/s eta 0:00:00a 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.4/64.4 kB 4.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 102.7 MB/s eta 0:00:0000:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 3.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 470.1/470.1 kB 31.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.3/79.3 kB 6.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 451.2/451.2 kB 32.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.8/41.8 kB 3.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.0/45.0 kB 3.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.5/155.5 kB 11.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 214.2/214.2 kB 16.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 86.9 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.2/74.2 kB 6.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 63.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 559.5/559.5 kB 36.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 60.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 3.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 381.2/381.2 kB 26.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.1/87.1 kB 7.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 3.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 105.9 MB/s eta 0:00:0000:01
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.39.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# google-adk 1.29.0 requires google-cloud-bigquery-storage>=2.0.0, which is not installed.
# kaggle-environments 1.29.3 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# sigstore 4.3.0 requires cryptography<49,>=42, but you have cryptography 49.0.0 which is incompatible.
# cesium 0.12.4 requires numpy<3.0,>=2.0, but you have numpy 1.26.4 which is incompatible.
# google-colab 1.0.0 requires jupyter-server==2.14.0, but you have jupyter-server 2.12.5 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.3.3 which is incompatible.
# dopamine-rl 4.1.2 requires gym<=0.25.2, but you have gym 0.26.2 which is incompatible.
# jaxlib 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# cupy-cuda12x 14.0.1 requires numpy<2.6,>=2.0, but you have numpy 1.26.4 which is incompatible.
# moviepy 1.0.3 requires decorator<5.0,>=4.0.2, but you have decorator 5.3.1 which is incompatible.
# opencv-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# tobler 0.14.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# jax 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# pydrive2 1.21.3 requires cryptography<44, but you have cryptography 49.0.0 which is incompatible.
# pyopenssl 24.2.1 requires cryptography<44,>=41.0.5, but you have cryptography 49.0.0 which is incompatible.
# opencv-python-headless 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# rasterio 1.5.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# pytensor 2.38.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# xarray-einstats 0.10.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# tifffile 2026.4.11 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# opencv-contrib-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# shap 0.51.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.

# %%
import yaml

# 1. Đọc (Load) file param.yaml
with open('/kaggle/working/neuro_symbolic_mlops_l2_app/params.yaml', 'r', encoding='utf-8') as file:
    params = yaml.safe_load(file)

# 2. Thay đổi nội dung (params hiện tại là một Dictionary)
params['data_dir'] =  "/kaggle/input/datasets/dangduykhoab2207532/vietnamese-cultural-dataset/vietnamese_cultural_dataset/vietnamese_cultural_dataset"
params['gflownet']['num_iterations'] = 1500
params['num_epochs'] = 5
params['gflownet']['max_rules'] = 120
params['gflownet']['beta'] = 1.0

print(yaml.dump(params, allow_unicode=True, default_flow_style=False))

# 3. Ghi đè (Save) lại vào file param.yaml
with open('/kaggle/working/neuro_symbolic_mlops_l2_app/params.yaml', 'w', encoding='utf-8') as file:
    yaml.safe_dump(params, file, default_flow_style=False, allow_unicode=True)

print("\n--- Đã cập nhật thành công file param.yaml! ---")
# Out:
# --- Nội dung ban đầu ---
# {'batch_size': 64, 'data_dir': '/kaggle/input/datasets/dangduykhoab2207532/vietnamese-cultural-dataset/vietnamese_cultural_dataset/vietnamese_cultural_dataset', 'gflownet': {'batch_size': 256, 'beta': 1.0, 'hidden_dim': 256, 'logZ_lr': 0.1, 'logZ_warmup_steps': 50, 'loss_type': 'tb', 'lr': 0.001, 'max_rules': 1300, 'num_iterations': 1500, 'val_samples': 140, 'validation_interval': 100, 'w_acc': 1.0, 'w_conflict': 0.5, 'w_cov': 0.5}, 'monitor_metric': 'val_loss', 'num_classes': 12, 'num_epochs': 5, 'num_workers': 4, 'output_dir': 'outputs', 'patience': 5, 'rule_penalty': {'final_temp': 15.0, 'initial_temp': 2.0, 'smoothing': 0.1, 'weight': 0.1}, 'rule_penalty_bayesian': {'K': 32, 'resolve_loss_conflict': True}, 'rule_ranking_analysis': {'K': 300}, 'rules': {'min_confidence': 0.7, 'min_support': 0.01}, 'seed': 42, 'transfer_learning': {'freeze_bn': True, 'freeze_schedule': {0: 'head_only', 5: 'last_block', 15: 'full'}, 'freeze_schedule_stage2': {0: 'last_block', 10: 'full'}, 'lr_backbone': 1e-05, 'lr_head': 0.0001}, 'weight_decay': 0.0001}
# batch_size: 64
# data_dir: /kaggle/input/datasets/dangduykhoab2207532/vietnamese-cultural-dataset/vietnamese_cultural_dataset/vietnamese_cultural_dataset
# gflownet:
#   batch_size: 256
#   beta: 1.0
#   hidden_dim: 256
#   logZ_lr: 0.1
#   logZ_warmup_steps: 50
#   loss_type: tb
#   lr: 0.001
#   max_rules: 120
#   num_iterations: 1500
#   val_samples: 140
#   validation_interval: 100
#   w_acc: 1.0
#   w_conflict: 0.5
#   w_cov: 0.5
# monitor_metric: val_loss
# num_classes: 12
# num_epochs: 5
# num_workers: 4
# output_dir: outputs
# patience: 5
# rule_penalty:
#   final_temp: 15.0
#   initial_temp: 2.0
#   smoothing: 0.1
#   weight: 0.1
# rule_penalty_bayesian:
#   K: 32
#   resolve_loss_conflict: true
# rule_ranking_analysis:
#   K: 300
# rules:
#   min_confidence: 0.7
#   min_support: 0.01
# seed: 42
# transfer_learning:
#   freeze_bn: true
#   freeze_schedule:
#     0: head_only
#     5: last_block
#     15: full
#   freeze_schedule_stage2:
#     0: last_block
#     10: full
#   lr_backbone: 1.0e-05
#   lr_head: 0.0001
# weight_decay: 0.0001
#
#
# --- Đã cập nhật thành công file param.yaml! ---

# %%
# %cd neuro_symbolic_mlops_l2_app
# Out:
# /kaggle/working/neuro_symbolic_mlops_l2_app

# %%
# %cd /kaggle/working

# %%
# !python -m pipelines.stage1_train_baseline --config /kaggle/working/neuro_symbolic_mlops_l2_app/params.yaml

# %%
# !python -m pipelines.stage2_extract_features --config /kaggle/working/neuro_symbolic_mlops_l2_app/params.yaml

# %%
# !python -m pipelines.stage3_extract_rules --config/kaggle/working/neuro_symbolic_mlops_l2_app/params.yaml

# %%
# !python -m experiments.sweep_reward_weights --config /kaggle/working/neuro_symbolic_mlops_l2_app/params.yaml

# %%
# !python -m pipelines.stage4_select_rules_gflownet --config /kaggle/working/neuro_symbolic_mlops_l2_app/params.yaml
# Out:
# Validate + build tensors: 100%|█████████████████| 33/33 [00:45<00:00,  1.38s/it]
# 2026-07-08 07:42:18 | INFO     | __main__ | Số luật hợp lệ sau khi lọc bằng val set: 1369
# 2026-07-08 07:42:18 | INFO     | src.gflownet.pipeline | Số luật hợp lệ: 1369 | loss_type: tb
# 2026-07-08 07:42:18 | INFO     | src.gflownet.pipeline | Đã lưu rule order + tensor (khớp index với gflownet_best.pth) tại outputs/04_filtered_rules/gflownet_rule_order.pkl
# GFlowNet (torchgfn):   7%| | 99/1500 [00:46<11:39,  2.00it/s, avg_log_r=1.260, g2026-07-08 07:43:06 | INFO     | src.gflownet.pipeline | Iter 100: ema=1.2578 best (120 rules)
# 2026-07-08 07:43:06 | INFO     | src.gflownet.pipeline | Loss= 3770.8325 : avg_log_r= 1.2598 : logZ= 6.4519 : grad_norm= 17958.9121 : lr= 0.001
# GFlowNet (torchgfn):  13%|▏| 199/1500 [01:30<02:51,  7.57it/s, avg_log_r=0.951, 2026-07-08 07:43:50 | INFO     | src.gflownet.pipeline | Iter 200: ema=1.1568 best (120 rules)
# 2026-07-08 07:43:50 | INFO     | src.gflownet.pipeline | Loss= 209.0282 : avg_log_r= 0.9505 : logZ= 6.6912 : grad_norm= 102.1465 : lr= 0.001
# GFlowNet (torchgfn):  20%|▏| 299/1500 [01:43<02:49,  7.09it/s, avg_log_r=0.971, 2026-07-08 07:44:03 | INFO     | src.gflownet.pipeline | Iter 300: ema=1.1020 best (120 rules)
# 2026-07-08 07:44:03 | INFO     | src.gflownet.pipeline | Loss= 157.1245 : avg_log_r= 0.9712 : logZ= 10.3900 : grad_norm= 79.9300 : lr= 0.001
# GFlowNet (torchgfn):  27%|▎| 399/1500 [01:57<02:39,  6.92it/s, avg_log_r=0.983, 2026-07-08 07:44:17 | INFO     | src.gflownet.pipeline | Iter 400: ema=1.0667 best (120 rules)
# 2026-07-08 07:44:17 | INFO     | src.gflownet.pipeline | Loss= 120.5334 : avg_log_r= 0.9834 : logZ= 14.8111 : grad_norm= 78.4309 : lr= 0.001
# GFlowNet (torchgfn):  33%|▎| 499/1500 [02:12<02:31,  6.59it/s, avg_log_r=1.013, 2026-07-08 07:44:32 | INFO     | src.gflownet.pipeline | Iter 500: ema=1.0497 best (120 rules)
# 2026-07-08 07:44:32 | INFO     | src.gflownet.pipeline | Loss= 110.5571 : avg_log_r= 1.0133 : logZ= 18.8920 : grad_norm= 90.8617 : lr= 0.0005
# GFlowNet (torchgfn):  40%|▍| 599/1500 [02:28<02:20,  6.40it/s, avg_log_r=1.020, 2026-07-08 07:44:47 | INFO     | src.gflownet.pipeline | Iter 600: ema=1.0401 best (120 rules)
# 2026-07-08 07:44:47 | INFO     | src.gflownet.pipeline | Loss= 115.9114 : avg_log_r= 1.0195 : logZ= 20.7828 : grad_norm= 100.2151 : lr= 0.0005
# GFlowNet (torchgfn):  47%|▍| 699/1500 [02:44<02:10,  6.14it/s, avg_log_r=1.030, 2026-07-08 07:45:04 | INFO     | src.gflownet.pipeline | Iter 700: ema=1.0389 best (120 rules)
# 2026-07-08 07:45:04 | INFO     | src.gflownet.pipeline | Loss= 111.3245 : avg_log_r= 1.0298 : logZ= 22.6256 : grad_norm= 96.1500 : lr= 0.0005
# GFlowNet (torchgfn):  53%|▌| 799/1500 [03:01<01:58,  5.91it/s, avg_log_r=1.032, 2026-07-08 07:45:20 | INFO     | src.gflownet.pipeline | Iter 800: ema=1.0344 best (120 rules)
# 2026-07-08 07:45:20 | INFO     | src.gflownet.pipeline | Loss= 99.3888 : avg_log_r= 1.0323 : logZ= 24.2493 : grad_norm= 137.1850 : lr= 0.0005
# GFlowNet (torchgfn):  60%|▌| 899/1500 [03:18<01:43,  5.81it/s, avg_log_r=1.017, 2026-07-08 07:45:38 | INFO     | src.gflownet.pipeline | Iter 900: ema=1.0289 best (120 rules)
# 2026-07-08 07:45:38 | INFO     | src.gflownet.pipeline | Loss= 118.2034 : avg_log_r= 1.0168 : logZ= 25.6476 : grad_norm= 169.0234 : lr= 0.00025
# GFlowNet (torchgfn):  67%|▋| 999/1500 [03:36<01:28,  5.65it/s, avg_log_r=1.036, 2026-07-08 07:45:56 | INFO     | src.gflownet.pipeline | Iter 1000: ema=1.0312 best (120 rules)
# 2026-07-08 07:45:56 | INFO     | src.gflownet.pipeline | Loss= 99.1291 : avg_log_r= 1.0365 : logZ= 26.2782 : grad_norm= 189.3038 : lr= 0.00025
# GFlowNet (torchgfn):  73%|▋| 1099/1500 [03:55<01:12,  5.52it/s, avg_log_r=1.029,2026-07-08 07:46:14 | INFO     | src.gflownet.pipeline | Iter 1100: ema=1.0304 best (120 rules)
# 2026-07-08 07:46:14 | INFO     | src.gflownet.pipeline | Loss= 91.9247 : avg_log_r= 1.0287 : logZ= 26.8644 : grad_norm= 168.4846 : lr= 0.00025
# GFlowNet (torchgfn):  80%|▊| 1199/1500 [04:13<00:58,  5.19it/s, avg_log_r=1.033,2026-07-08 07:46:33 | INFO     | src.gflownet.pipeline | Iter 1200: ema=1.0296 best (120 rules)
# 2026-07-08 07:46:33 | INFO     | src.gflownet.pipeline | Loss= 83.8571 : avg_log_r= 1.0327 : logZ= 27.4755 : grad_norm= 193.2823 : lr= 0.00025
# GFlowNet (torchgfn):  87%|▊| 1299/1500 [04:32<00:37,  5.36it/s, avg_log_r=1.045,2026-07-08 07:46:52 | INFO     | src.gflownet.pipeline | Iter 1300: ema=1.0353 best (120 rules)
# 2026-07-08 07:46:52 | INFO     | src.gflownet.pipeline | Loss= 83.6046 : avg_log_r= 1.0454 : logZ= 28.0618 : grad_norm= 160.5733 : lr= 0.000125
# GFlowNet (torchgfn):  93%|▉| 1399/1500 [04:51<00:18,  5.39it/s, avg_log_r=1.047,2026-07-08 07:47:11 | INFO     | src.gflownet.pipeline | Iter 1400: ema=1.0386 best (120 rules)
# 2026-07-08 07:47:11 | INFO     | src.gflownet.pipeline | Loss= 80.4538 : avg_log_r= 1.0473 : logZ= 28.3560 : grad_norm= 156.5359 : lr= 0.000125
# GFlowNet (torchgfn): 100%|▉| 1499/1500 [05:11<00:00,  5.23it/s, avg_log_r=1.049,2026-07-08 07:47:31 | INFO     | src.gflownet.pipeline | Iter 1500: ema=1.0417 best (120 rules)
# 2026-07-08 07:47:31 | INFO     | src.gflownet.pipeline | Loss= 87.9825 : avg_log_r= 1.0490 : logZ= 28.6677 : grad_norm= 226.0491 : lr= 0.000125
# GFlowNet (torchgfn): 100%|█| 1500/1500 [05:11<00:00,  4.81it/s, avg_log_r=1.049,
# 2026-07-08 07:47:31 | INFO     | src.gflownet.pipeline | DEBUG best_selected_ever: n_selected=120, accuracy=0.9211, coverage=0.9005, redundancy=0.0256, redundancy_conflict=0.1715, complexity=1.0000, f1_like=0.9107
# 2026-07-08 07:47:31 | INFO     | src.gflownet.pipeline | DEBUG final_selected (returned): n_selected=120, accuracy=0.9211, coverage=0.9005, redundancy=0.0256, redundancy_conflict=0.1715, complexity=1.0000, f1_like=0.9107
# 2026-07-08 07:47:31 | INFO     | src.gflownet.pipeline | Final: 120 rules, best=1.2856
# WARNING:dvclive:Error in save_dvc_exp: output 'outputs/04_filtered_rules/rule_ranking_analysis.csv' does not exist
# 2026-07-08 07:47:33 | INFO     | __main__ | Stage 4 hoàn thành. 120 luật được GFlowNet chọn.

# %%
# !python -m pipelines.stage5_train_rule_regularized --config /kaggle/working/neuro_symbolic_mlops_l2_app/params.yaml

# %%
# !python -m pipelines.stage5_train_rule_regularized_heuristics  --config /kaggle/working/neuro_symbolic_mlops_l2_app/params.yaml

# %%
! python -m pipelines.stage5_train_rule_bayesian --config /kaggle/working/neuro_symbolic_mlops_l2_app/params.yaml
# Out:
# 2026-07-08 07:49:15 | INFO     | __main__ | Đã nạp frozen GFlowNet sampler từ outputs/04_filtered_rules/gflownet_best.pth (1369 luật, loss_type=tb).
# 2026-07-08 07:49:16 | INFO     | src.training.trainer | EarlyStopping theo dõi 'val_loss' (mode='min')
# 2026-07-08 07:49:16 | INFO     | src.training.trainer | Dùng penalty_module được truyền sẵn: BayesianRuleMarginalization
# 2026-07-08 07:49:16 | INFO     | src.training.trainer | Bật xử lý xung đột gradient (PCGrad) giữa CE loss và rule-penalty loss.
# 2026-07-08 07:49:17 | INFO     | src.training.trainer | Epoch 0: chuyển freeze_stage -> 'head_only'
# 2026-07-08 07:50:09 | INFO     | src.training.trainer | Epoch 1/5 | Train Loss 1.9738 | Train Acc 0.6146 | CE 1.7422 | Penalty 0.2316 | Val Loss 1.1630 | Val Acc 0.8220 | LRs head:1.00e-04
# 2026-07-08 07:50:09 | INFO     | src.training.trainer |   Rule coverage: 39/1369 luật active (2.9%) | mean_rule_sat=0.0037 | T=2.00 | grad_conflict_ratio=0.79
# 2026-07-08 07:50:59 | INFO     | src.training.trainer | Epoch 2/5 | Train Loss 1.3898 | Train Acc 0.7855 | CE 1.1561 | Penalty 0.2336 | Val Loss 0.9681 | Val Acc 0.8584 | LRs head:1.00e-04
# 2026-07-08 07:50:59 | INFO     | src.training.trainer |   Rule coverage: 133/1369 luật active (9.7%) | mean_rule_sat=0.0063 | T=5.25 | grad_conflict_ratio=1.00
# 2026-07-08 07:51:49 | INFO     | src.training.trainer | Epoch 3/5 | Train Loss 1.2575 | Train Acc 0.8202 | CE 1.0477 | Penalty 0.2098 | Val Loss 0.9059 | Val Acc 0.8785 | LRs head:1.00e-04
# 2026-07-08 07:51:49 | INFO     | src.training.trainer |   Rule coverage: 203/1369 luật active (14.8%) | mean_rule_sat=0.0077 | T=8.50 | grad_conflict_ratio=0.92
# 2026-07-08 07:52:40 | INFO     | src.training.trainer | Epoch 4/5 | Train Loss 1.1882 | Train Acc 0.8356 | CE 0.9995 | Penalty 0.1887 | Val Loss 0.8780 | Val Acc 0.8911 | LRs head:1.00e-04
# 2026-07-08 07:52:40 | INFO     | src.training.trainer |   Rule coverage: 245/1369 luật active (17.9%) | mean_rule_sat=0.0086 | T=11.75 | grad_conflict_ratio=0.89
# 2026-07-08 07:53:31 | INFO     | src.training.trainer | Epoch 5/5 | Train Loss 1.1368 | Train Acc 0.8499 | CE 0.9630 | Penalty 0.1738 | Val Loss 0.8593 | Val Acc 0.8958 | LRs head:1.00e-04
# 2026-07-08 07:53:31 | INFO     | src.training.trainer |   Rule coverage: 283/1369 luật active (20.7%) | mean_rule_sat=0.0093 | T=15.00 | grad_conflict_ratio=0.85
# WARNING:dvclive:Error in save_dvc_exp: output 'outputs/04_filtered_rules/rule_ranking_analysis.csv' does not exist
# 2026-07-08 07:53:32 | INFO     | src.training.trainer | Nhiệt độ dừng ở 15.00 (100.0% quãng đường ủ dự kiến)
# 2026-07-08 07:53:32 | INFO     | src.training.trainer | Training complete in 4.27 minutes | Best Val Acc: 0.8958
# 2026-07-08 07:53:37 | INFO     | src.evaluation.evaluate | Rule-Regularized CNN Performance (Bayesian marginalization) | Overall Accuracy: 88.28%
# 2026-07-08 07:53:40 | INFO     | __main__ | Stage 5 (Bayesian marginalization) hoàn thành.
